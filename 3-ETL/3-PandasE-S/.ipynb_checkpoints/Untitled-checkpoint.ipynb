# %% [markdown]
# ## **Aula  - 1.Leyendo archivos CSV**

# %% [markdown]
# ### **Importando archivos CSV**

# %%
import pandas as pd

# %%
pd.read_csv('/media/betorock/Cursos/Cursos_2025/DataScience_AluraLatam/3-ETL/3-PandasE-S/data/superstore_data.csv')
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
# gusrdamo en variable datos
datos = pd.read_csv('/media/betorock/Cursos/Cursos_2025/DataScience_AluraLatam/3-ETL/3-PandasE-S/data/superstore_data.csv')

# %%
datos.head(5)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
# archivo separado por punto y coma
datos_punto_coma = pd.read_csv('/media/betorock/Cursos/Cursos_2025/DataScience_AluraLatam/3-ETL/3-PandasE-S/data/superstore_data_punto_coma.csv')

# %%
datos_punto_coma.head(5)
# Out:
#   Id;Year_Birth;Education;Marital_Status;Income;Kidhome;Teenhome;Dt_Customer;Recency;MntWines;MntFruits;MntMeatProducts;MntFishProducts;MntSweetProducts;MntGoldProds;NumDealsPurchases;NumWebPurchases;NumCatalogPurchases;NumStorePurchases;NumWebVisitsMonth;Response;Complain
# 0  1826;1970;Graduation;Divorced;84835;0;0;6/16/2...
# 1  1;1961;Graduation;Single;57091;0;0;6/15/2014;0...
# 2  10476;1958;Graduation;Married;67267;0;1;5/13/2...
# 3  1386;1967;Graduation;Together;32474;1;1;11/5/2...
# 4  5371;1989;Graduation;Single;21474;1;0;8/4/2014...

# %% [markdown]
# ### Parámetros de la función read_csv

# %% [markdown]
# Documentación: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
# utilizamos el separador ;
datos_punto_coma = pd.read_csv('/media/betorock/Cursos/Cursos_2025/DataScience_AluraLatam/3-ETL/3-PandasE-S/data/superstore_data_punto_coma.csv', sep=';')

# %%
datos_punto_coma.head(5)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
# utilizaremos el parametro nrows(nos mostrara la cantidad de filas que le indiquemos)
datos_primeras_lineas = pd.read_csv('/media/betorock/Cursos/Cursos_2025/DataScience_AluraLatam/3-ETL/3-PandasE-S/data/superstore_data.csv', nrows = 5)
datos_primeras_lineas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
# utilizaremos el parametro usecols (nos mostrara la cantidad de columnas que le indiquemos) para restringuir la cantidad de columnas a leer
datos_seleccion = pd.read_csv('/media/betorock/Cursos/Cursos_2025/DataScience_AluraLatam/3-ETL/3-PandasE-S/data/superstore_data.csv', usecols = ['Id','Year_Birth','Income'])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
# de esta manera para mostrar las columnas y no utilizar sus nombres sino que su posicion 
datos_seleccion = pd.read_csv('/media/betorock/Cursos/Cursos_2025/DataScience_AluraLatam/3-ETL/3-PandasE-S/data/superstore_data.csv', usecols = [0,1,4])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ### **Escribiendo archivos CSV**

# %% [markdown]
# Documentación: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html

# %%
datos_seleccion.to_csv('clientes_mercado.csv')

# %%
clientes_mercado = pd.read_csv('/media/betorock/Cursos/Cursos_2025/DataScience_AluraLatam/3-ETL/3-PandasE-S/.ipynb_checkpoints/clientes_mercado.csv')

# %%
clientes_mercado
# Out:
#       Unnamed: 0     Id  Year_Birth   Income
# 0              0   1826        1970  84835.0
# 1              1      1        1961  57091.0
# 2              2  10476        1958  67267.0
# 3              3   1386        1967  32474.0
# 4              4   5371        1989  21474.0
# ...          ...    ...         ...      ...
# 2235        2235  10142        1976  66476.0
# 2236        2236   5263        1977  31056.0
# 2237        2237     22        1976  46310.0
# 2238        2238    528        1978  65819.0
# 2239        2239   4070        1969  94871.0
#
# [2240 rows x 4 columns]

# %%
datos_seleccion.to_csv('datos_mercado.csv', index=False)

# %%
datos_mercado = pd.read_csv('/media/betorock/Cursos/Cursos_2025/DataScience_AluraLatam/3-ETL/3-PandasE-S/.ipynb_checkpoints/datos_mercado.csv')

# %%
datos_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ## **Desafío: leyendo datos con múltiples parámetros**

# %% [markdown]
# #### Es hora de que pongas a prueba los conocimientos desarrollados durante la clase. Disponemos de un archivo en formato CSV, el cual se obtuvo de la página Información de Salud (TABNET) - DATASUS. Este archivo contiene los gastos hospitalarios públicos de cada una de las Unidades de la Federación Brasileña desde enero de 2008 hasta marzo de 2021.
#
# Su desafío aquí será leer este archivo usando la función read_csv de la biblioteca Pandas. Se deben agregar algunos parámetros para que la lectura se realice correctamente. Entonces, aquí hay algunos consejos:
#
#     1.Asegúrese de que el archivo CSV esté separado por una coma o punto y coma.
#     2.La codificación del archivo es ISO-8859-1.
#     3.Las primeras tres líneas del archivo se pueden ignorar, ya que el encabezado sólo comienza en la cuarta línea.
#     4.Las últimas 9 líneas también se pueden ignorar, ya que son sólo información sobre dónde se tomaron los datos.
#     5.Para eliminar las últimas líneas es necesario agregar el parámetro engine='python'

# %%
salud = pd.read_csv('/media/betorock/Cursos/Cursos_2025/DataScience_AluraLatam/3-ETL/3-PandasE-S/data/datos_sus.csv', sep=';', encoding='ISO-8859-1', header=2, engine='python')

# %%
salud.head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
