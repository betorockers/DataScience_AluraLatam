# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## **PROBLEMA DE NEGOCIO**

# %% [markdown]
# Se trata de un algoritmo capaz de analizar las caracteristicas de una propiedad -como comodidades, tamaño, ocupacion del espacio en un periodo determinado- y sugerir al anfitrión un precio a cobrar por tarifas diarias que garantice ganancias en momentos de alta demanda.
#
#     - Pricing inteligence

# %% [markdown]
# ### **1. Entendiendo el Problema**

# %%
# importamos los archivos 
datos = pd.read_json('../Data/datos_hosting.json')
datos.head()
# Out:
#                                       info_inmuebles
# 0  {'evaluacion_general': '10.0', 'experiencia_lo...
# 1  {'evaluacion_general': '10.0', 'experiencia_lo...
# 2  {'evaluacion_general': '10.0', 'experiencia_lo...
# 3  {'evaluacion_general': '10.0', 'experiencia_lo...
# 4  {'evaluacion_general': '10.0', 'experiencia_lo...

# %%
# Normalizamos los datos importados para poder analizarlos mejor
datos = pd.json_normalize(datos['info_inmuebles'])
datos.head()
# Out:
#   evaluacion_general experiencia_local max_hospedes  \
# 0               10.0                --            1
# 1               10.0                --           10
# 2               10.0                --           11
# 3               10.0                --           12
# 4               10.0                --           14
#
#                                    descripcion_local  \
# 0  [This clean and comfortable one bedroom sits r...
# 1  [Welcome to the heart of the 'Ballard Brewery ...
# 2  [New modern house built in 2013.  Spectacular ...
# 3  [Our NW style home is 3200+ sq ft with 3 level...
# 4  [Perfect for groups. 2 bedrooms, full bathroom...
#
#                                 descripcion_vecindad  \
# 0  [Lower Queen Anne is near the Seattle Center (...
# 1  [--, Capital Hill is the heart of Seattle, bor...
# 2  [Upper Queen Anne is a charming neighborhood f...
# 3  [The Views from our top floor!  Wallingford ha...
# 4  [Safeway grocery store within walking distance...
#
# ...

# %%
#datos.info()

# %% [markdown]
# ### **2. datos numéricos**

# %%
# extraeremos los registros de cada elemento en las columnas
columnas = list(datos.columns)
columnas
# Out:
# ['evaluacion_general',
#  'experiencia_local',
#  'max_hospedes',
#  'descripcion_local',
#  'descripcion_vecindad',
#  'cantidad_baños',
#  'cantidad_cuartos',
#  'cantidad_camas',
#  'modelo_cama',
#  'comodidades',
#  'cuota_deposito',
#  'cuota_limpieza',
#  'precio']

# %%
# utilizaremos el metodo explode para revisar las listas desde la columna descripcion_local
data = datos.explode(columnas[3:])
data
# Out:
#    evaluacion_general experiencia_local max_hospedes  \
# 0                10.0                --            1
# 0                10.0                --            1
# 0                10.0                --            1
# 0                10.0                --            1
# 0                10.0                --            1
# ..                ...               ...          ...
# 68                nan                --            8
# 68                nan                --            8
# 68                nan                --            8
# 69                nan                --            9
# 69                nan                --            9
#
#                                     descripcion_local  \
# 0   This clean and comfortable one bedroom sits ri...
# 0   Our century old Upper Queen Anne house is loca...
# 0   Cozy room in two-bedroom apartment along the l...
# 0   Very lovely and cozy room for one. Convenientl...
# ...

# %%
# dejaremos los indices en numeros no repetidos(recetearemos los indices)
data.reset_index(inplace = True, drop = True)
data.head()
# Out:
#   evaluacion_general experiencia_local max_hospedes  \
# 0               10.0                --            1
# 1               10.0                --            1
# 2               10.0                --            1
# 3               10.0                --            1
# 4               10.0                --            1
#
#                                    descripcion_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descripcion_vecindad cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...              1
# 1  Upper Queen Anne is a really pleasant, unique ...              1
# 2  The convenience of being in Seattle but on the...              1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   object
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   object
#  6   cantidad_cuartos      3818 non-null   object
#  7   cantidad_camas        3818 non-null   object
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: object(13)
# memory usage: 387.9+ KB

# %%
# tranformaremos los datos para que cada columna muestre el dato que tiene correctamente utilizaremos la biblioteca numpy(este metodo no funcionara si algun dato de la columna no es entero)
data['max_hospedes'] = data['max_hospedes'].astype(np.int64)

# %%
# trasformamos las siguientes columnas que contienen numeros enteros
col_numericas = ['cantidad_baños', 'cantidad_cuartos', 'cantidad_camas']

# %%
data[col_numericas] = data[col_numericas].astype(np.int64)

# %%
# ahora trasnformaremos las columnas con numeros decimales
data['evaluacion_general'] = data['evaluacion_general'].astype(np.float64)

# %%
# ahora trasnformaremos las columnas con numeros decimales y caracteres asociados($) utilizando el metodo apply() con una funcion lambda,si trabajo con series
data['precio'] = data['precio'].apply(lambda x: x.replace('$', '').replace(',', '').strip())

# %%
data['precio'] = data['precio'].astype(np.float64)

# %%
data['precio'].astype(np.float64)
# Out:
# 0       110.0
# 1        45.0
# 2        55.0
# 3        52.0
# 4        85.0
#         ...
# 3813    299.0
# 3814    199.0
# 3815    400.0
# 3816    250.0
# 3817    350.0
# Name: precio, Length: 3818, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 387.9+ KB

# %%
# ahora trasnformaremos las columnas con numeros decimales y caracteres asociados($, ',') utilizando el metodo applymap() con una funcion lambda,si trabajo con DataFrame
data[['cuota_deposito', 'cuota_limpieza']] = data[['cuota_deposito', 'cuota_limpieza']].applymap(lambda x,: x.replace('$', '').replace(',', '').strip())
# Out:
# /tmp/ipykernel_7606/1749442533.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data[['cuota_deposito', 'cuota_limpieza']] = data[['cuota_deposito', 'cuota_limpieza']].applymap(lambda x,: x.replace('$', '').replace(',', '').strip())

# %%
# ahora si transformamos a tipo float64
data[['cuota_deposito', 'cuota_limpieza']] = data[['cuota_deposito', 'cuota_limpieza']].astype(np.float64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   float64
#  11  cuota_limpieza        3818 non-null   float64
#  12  precio                3818 non-null   float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 387.9+ KB

# %% [markdown]
# ### **3.Datos de texto**

# %%
data.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
# transformaremos los textos de las columnas en palabras o tockens
data['descripcion_local']
# Out:
# 0       This clean and comfortable one bedroom sits ri...
# 1       Our century old Upper Queen Anne house is loca...
# 2       Cozy room in two-bedroom apartment along the l...
# 3       Very lovely and cozy room for one. Convenientl...
# 4       The “Studio at Mibbett Hollow' is in a Beautif...
#                               ...
# 3813    Beautiful craftsman home in the historic Wedgw...
# 3814    Located in a very easily accessible area of Se...
# 3815    This home is fully furnished and available wee...
# 3816    This business-themed modern home features:  *H...
# 3817    This welcoming home is in the quiet residentia...
# Name: descripcion_local, Length: 3818, dtype: object

# %%
# transformaremos en string, luego en minusculas y luego lo almacenamos en una variable
data['descripcion_local'] = data['descripcion_local'].str.lower()

# %%
data.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  this clean and comfortable one bedroom sits ri...
# 1  our century old upper queen anne house is loca...
# 2  cozy room in two-bedroom apartment along the l...
# 3  very lovely and cozy room for one. convenientl...
# 4  the “studio at mibbett hollow' is in a beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
data['descripcion_vecindad'] = data['descripcion_vecindad'].str.lower()

# %%
data.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  this clean and comfortable one bedroom sits ri...
# 1  our century old upper queen anne house is loca...
# 2  cozy room in two-bedroom apartment along the l...
# 3  very lovely and cozy room for one. convenientl...
# 4  the “studio at mibbett hollow' is in a beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  lower queen anne is near the seattle center (s...               1
# 1  upper queen anne is a really pleasant, unique ...               1
# 2  the convenience of being in seattle but on the...               1
# ...

# %%
# eliminaremos caracteres especiales que no utilizaremos, para esto usaremos str y regex(expresiones regulares)
data['descripcion_local'][3169]
# Out:
# "built, run and supported by seattle tech and start up veterans, grokhome's focus is to create a supportive environment for smart people working on interesting projects, start ups and more. this listing is an upper bunk, in a 2-person shared room. *note: this fall, there will be major renovations happening on one kitchen and bathroom at a time. there will always be two other working kitchens and two working bathrooms in the house. we'll work to minimize the impact these renovations have on your stay. **this listing is only available to those working in the tech/science space. live in a hacker house, and immerse yourself in the seattle tech scene. you can expect to be surrounded by smart people solving big problems or working on something fun. we have frequent demo nights, and love when our guests share something they are passionate about. if you're new to the city, our deep ties to the seattle tech scene can help you get involved. expand your network, develop your ideas, and learn so
# ...

# %%
# utilizaremos regex
data['descripcion_local'] = data['descripcion_local'].str.replace('[^a-zA-Z0-9\-\']',' ',regex=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\-'
# <>:2: SyntaxWarning: invalid escape sequence '\-'
# /tmp/ipykernel_7606/1273188213.py:2: SyntaxWarning: invalid escape sequence '\-'
#   data['descripcion_local'] = data['descripcion_local'].str.replace('[^a-zA-Z0-9\-\']',' ',regex=True)

# %%
# Eliminaremos los guiones que no correspondan a palabras compuestas ejemplo 2-persons, pero si eliminamos el guion si se utiliza como separador one - two
data['descripcion_local'] = data['descripcion_local'].str.replace('(?<!\w)-(?>!\w)',' ',regex=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_7606/1466299016.py:2: SyntaxWarning: invalid escape sequence '\w'
#   data['descripcion_local'] = data['descripcion_local'].str.replace('(?<!\w)-(?>!\w)',' ',regex=True)

# %%
data['descripcion_local'].head()
# Out:
# 0    this clean and comfortable one bedroom sits ri...
# 1    our century old upper queen anne house is loca...
# 2    cozy room in two-bedroom apartment along the l...
# 3    very lovely and cozy room for one  convenientl...
# 4    the  studio at mibbett hollow' is in a beautif...
# Name: descripcion_local, dtype: object

# %%
# Comenzaremos con la tokenizacion, utilizaremos el metodo de split()
data['descripcion_local'].str.split()
# Out:
# 0       [this, clean, and, comfortable, one, bedroom, ...
# 1       [our, century, old, upper, queen, anne, house,...
# 2       [cozy, room, in, two-bedroom, apartment, along...
# 3       [very, lovely, and, cozy, room, for, one, conv...
# 4       [the, studio, at, mibbett, hollow', is, in, a,...
#                               ...
# 3813    [beautiful, craftsman, home, in, the, historic...
# 3814    [located, in, a, very, easily, accessible, are...
# 3815    [this, home, is, fully, furnished, and, availa...
# 3816    [this, business-themed, modern, home, features...
# 3817    [this, welcoming, home, is, in, the, quiet, re...
# Name: descripcion_local, Length: 3818, dtype: object

# %%
data['descripcion_local'] = data['descripcion_local'].str.split()

# %%
data.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  lower queen anne is near the seattle center (s...               1
# 1  upper queen anne is a really pleasant, unique ...               1
# 2  the convenience of being in seattle but on the...               1
# ...

# %%
data['comodidades'].str.replace('\{|}|\"','', regex=True)
data['comodidades'] = data['comodidades'].str.replace('\{|}|\"','', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\{'
# <>:2: SyntaxWarning: invalid escape sequence '\{'
# <>:1: SyntaxWarning: invalid escape sequence '\{'
# <>:2: SyntaxWarning: invalid escape sequence '\{'
# /tmp/ipykernel_7606/1760057835.py:1: SyntaxWarning: invalid escape sequence '\{'
#   data['comodidades'].str.replace('\{|}|\"','', regex=True)
# /tmp/ipykernel_7606/1760057835.py:2: SyntaxWarning: invalid escape sequence '\{'
#   data['comodidades'] = data['comodidades'].str.replace('\{|}|\"','', regex=True)

# %%
data['comodidades'] = data['comodidades'].str.split(',')

# %%
data['descripcion_vecindad'].str.split()
# Out:
# 0       [lower, queen, anne, is, near, the, seattle, c...
# 1       [upper, queen, anne, is, a, really, pleasant,,...
# 2       [the, convenience, of, being, in, seattle, but...
# 3       [ballard, is, lovely,, vibrant, and, one, of, ...
# 4                                                    [--]
#                               ...
# 3813                                                 [--]
# 3814    [quiet,, dead, end, street, near, i-5., the, p...
# 3815                                                 [--]
# 3816    [your, hosts, made, madison, valley, their, ho...
# 3817    [despite, the, quiet,, leafy, streets, of, thi...
# Name: descripcion_vecindad, Length: 3818, dtype: object

# %%
data['descripcion_vecindad'] = data['descripcion_vecindad'].str.split()

# %%
data.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  [lower, queen, anne, is, near, the, seattle, c...               1
# 1  [upper, queen, anne, is, a, really, pleasant,,...               1
# 2  [the, convenience, of, being, in, seattle, but...               1
# ...
